# %% [markdown]
# # Assignment 2: Pattern Mining
#
# **Deadline**: 20 April 2026
#
# **Name**: YOUR_NAME
#
# **Matriculation Number**: YOUR_MATRICULATION_NUMBER
#
# **Packages**: Pandas, Mlxtend
#
# **Submission Instructions**: Upload your Jupyter notebook and a PDF export (with results) on Moodle. Go then to the corresponding checkmark list to indicate which tasks you have completed and feel confident to explain in class. The checkmark list will be the basis for grading. If you indicate on Moodle to be able to explain a solution to a task but then fail to appropriately explain the submitted solution, including the motivation for individual steps, during the assignment review, you will fail the course. If you indicate that you solved a specific task but the task was clearly not solved, you will fail the course.
#
# Write your solutions in the code cells for the different tasks. You may also add additional code cells as well as markdown cells if you want to write down additional explanations, observations, or assumptions.
#
# There are also questions that require you to write textual answers into markdown cells.
#
# **Note**: The tables shown in the PDF export of this notebook on Moodle are only illustrative. You may obtain different numbers.

# %% [markdown]
# ## Case 1: Product Orders
#
# **Files**: store.csv
#
# You have a dataset of orders along with product and customer information. Each order comprises multiple items. Each row in the dataset represents an order item. You should conduct a market basket analysis by mining for frequent patterns and association rules.
#
# To be able to mine for frequent patterns and association rules, you have to first preprocess the data using pandas to obtain transactions. The following KNIME workflow illustrates the preprocessing steps. If you cannot preprocess the data using pandas, you may also use the output of the KNIME workflow as the starting point for association rule mining.
#
# ![KNIME workflow of the preprocessing of product orders](resources/KNIME-workflow_01-store-data.png "Preprocessing of store data with KNIME")

# %%
# Imports
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ### Task 1.1: Read the file
#
# Use pandas to read the CSV file. Choose the right encoding and make *Category* a string column. Show the first couple of rows of the dataframe.

# %% [markdown]
# ### Task 1.2: Obtain the transactions with products
#
# Use pandas to group the rows by *Order.ID* and aggregate the *Product.ID* values into a list for each order.
# For convenience, rename the *Product.ID* column to *Items* and drop the *Order.ID* column.
# Show the first couple of rows of the resulting dataframe.

# %% [markdown]
# ### Task 1.3: Obtain the transactions with subcategories
#
# Use pandas to group the rows by *Order.ID* and aggregate the *Sub.Category* values into a list for each order.
# For convenience, rename the *Sub.Category* column to *Items* and drop the *Order.ID* column.
# Show the first couple of rows of the resulting dataframe.

# %% [markdown]
# ### Task 1.4: Obtain the transactions with categories
#
# Use pandas to group the rows by *Order.ID* and aggregate the *Category* values into a list for each order.
# For convenience, rename the *Category* column to *Items* and drop the *Order.ID* column.
# Show the first couple of rows of the resulting dataframe.

# %% [markdown]
# ### Task 1.5: Obtain the transactions with subcategories and categories
#
# Use pandas to obtain transactions with a *set* of categories and subcategories instead of the individual categories/subcategories.
# For convenience, rename your column containing the *set* of categories and subcategories to *Items* and drop the other columns.
# Show the first couple of rows of the resulting dataframe.

# %% [markdown]
# ### Task 1.6: Transform the transactions with products into the required format
#
# Obtain a one-hot encoded representation of the transactions with products in the format required by the Mlxtend framework.
# Use the one-hot encoded representation to create a dataframe with the respective products as columns and show the first couple of rows.

# %% [markdown]
# ### Task 1.7: Transform the transactions with subcategories into the required format
#
# Obtain a one-hot encoded representation of the transactions with subcategories in the format required by the Mlxtend framework. Use the one-hot encoded representation to create a dataframe with the respective subcategories as columns and show the first couple of rows.

# %% [markdown]
# ### Task 1.8: Transform the transactions with categories into the required format
#
# Obtain a one-hot encoded representation of the transactions with categories in the format required by the Mlxtend framework.
# Use the one-hot encoded representation to create a dataframe with the respective categories as columns and show the first couple of rows.

# %% [markdown]
# ### Task 1.9: Transform the transactions with subcategories and categories into the required format
#
# Obtain a one-hot encoded representation of the transactions with subcategories and categories in the format required by the Mlxtend framework.
# Use the one-hot encoded representation to create a dataframe with the respective categories and subcategories as columns and show the first couple of rows.

# %% [markdown]
# ### Task 1.10: Mine for frequent itemsets with products
#
# Use the Mlxtend framework to mine for frequent itemsets in the transactions with products having a minimum support of 0.1 %.
# Add a column *length* indicating the length of the itemset and a column *support_count* indicating the support count of the itemset.
# Sort the dataframe by the support count in descending order and show all rows.

# %% [markdown]
# ### Task 1.11: Mine for frequent itemsets and association rules with subcategories
#
# Use the Mlxtend framework to mine for frequent itemsets in the transactions with subcategories having a minimum support of 0.5 %.
# Add a column *length* indicating the length of the itemset and a column *support_count* indicating the support count of the itemset.
# Sort the dataframe by the support count in descending order and show the first couple of rows.
#
# Try to find association rules with a minimum lift of 1 and sort the rules by Kulczynski measure in descending order.
# Show the first couple of rows of the dataframe, limited to the columns *antecedents*, *consequents*, *support*, *confidence*, *lift*, and *kulczynski*.
#
# Finally, interpret the interestingness of the found rules. Write your textual answer in the markdown cell below.

# %% [markdown]
# **How do you interpret the interestingness of the found rules?**
#
# -> PUT YOUR ANSWER HERE <-

# %% [markdown]
# ### Task 1.12: Mine for frequent itemsets and association rules with categories
#
# Use the Mlxtend framework to mine for frequent itemsets in the transactions with categories having a minimum support of 1.0 %.
# Add a column *length* indicating the length of the itemset and a column *support_count* indicating the support count of the itemset.
# Sort the dataframe by the support count in descending order and show the first couple of rows.
#
# Try to find association rules with a minimum lift of 1 and sort the rules by Kulczynski measure in descending order.
# Show the first couple of rows of the dataframe, limited to the columns *antecedents*, *consequents*, *support*, *confidence*, *lift*, and *kulczynski*.
#
# Finally, interpret the interestingness of the found rules. Write your textual answer in the markdown cell below.

# %% [markdown]
# **How do you interpret the interestingness of the found rules?**
#
# -> PUT YOUR ANSWER HERE <-

# %% [markdown]
# ### Task 1.13: Mine for frequent itemsets and association rules with subcategories and categories
#
# Use the Mlxtend framework to mine for frequent itemsets in the transactions with subcategories and categories having a minimum support of 0.5 %.
# Add a column *length* indicating the length of the itemset and a column *support_count* indicating the support count of the itemset.
# Sort the dataframe by the support count in descending order and show the first and lasat couple of rows.
#
# Try to find association rules with a minimum lift of 1 and sort the rules by Kulczynski measure in descending order.
# Show the first couple of rows of the dataframe, limited to the columns *antecedents*, *consequents*, *support*, *confidence*, *lift*, and *kulczynski*.

# %% [markdown]
# ### Task 1.14: Get mappings from subcategories to categories
#
# Create a map (dictionary) of subcatgories to categories from the base dataframe where subcategories are keys and categories are values.

# %% [markdown]
# ### Task 1.15: Remove trivial rules
#
# Use the mappings from subcategories to categories, i.e., the dictionary from Task 1.14, to filter out trivial rules where the category of a subcategory in the antecedents is in the consequents, and vice versa.
# For example, a rule *Phones, Chairs => 3* is a trivial rule because *Phones* belongs to category *3*.
#
# Sort the rules by Kulczynski measure in descending order and show the first couple of rows of the dataframe, limited to the columns *antecedents*, *consequents*, *support*, *confidence*, *lift*, and *kulczynski*.
#
# Finally, interpret the interestingness of the found rules. Write your textual answer in the markdown cell below.

# %% [markdown]
# **How do you interpret the interestingness of the found rules?**
#
# -> PUT YOUR ANSWER HERE <-

# %% [markdown]
# ## Case 2: Health Records
#
# **Files**: health.csv
#
# You have a dataset of health reports. Each report consists of multiple entries, which can be
#
# - the diagnosis of a condition (type = 'C'),
# - the observation of a symptom (type = 'S'),
# - a prescribed treatment (type = 'T'),
# - a note by the acting medical doctor (type = 'N'),
# - or a weather observation (type = 'W').
#
# You should mine for frequent patterns and association rules between conditions, symptoms, treatments, etc.
#
# To be able to mine for frequent patterns and association rules, you have to first preprocess the data using pandas to obtain transactions. The following KNIME workflow illustrates the preprocessing steps. If you cannot preprocess the data using pandas, you may also use the output of the KNIME workflow as the starting point for association rule mining.
#
# ![KNIME workflow of the preprocessing of product orders](resources/KNIME-workflow_02-health-data.png "Preprocessing of health data with KNIME")

# %%
# Imports
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ### Task 2.1: Write a function to handle bad lines
#
# Write a function **handle_bad_line** that takes a list of string values as input parameter and returns a (repaired) list of string values or *None* as output.
#
# In case of a line with more than seven columns, this function should be called to concatenate all string values after the seventh entry into a single string, using commas to separate the original values.
# The function should then return a list of string values with exactly seven entries, or *None* if that is not possible.

# %%
# Define a custom function to handle bad lines
def handle_bad_line(bad_line: list) -> list | None:
    raise NotImplementedError('TOOD: Implement this function')

# %%
# Exemplary bad line
original_list = ['this', 'list', 'has', 'too', 'many', 'entries', '!', '!', '!']

print('Example of how the function should processes a bad line:')
print(f'\t- Original list (bad line) with length {len(original_list)}:\n\t{original_list}')

repaired_list = handle_bad_line(original_list)
print(f'\t- Repaired list (processed bad line by function) with length {len(repaired_list)}:\n\t{repaired_list}')

# %% [markdown]
# ### Task 2.2: Read the file
#
# Read the CSV file into a pandas dataframe. The file contains *bad lines*, i.e., lines with more columns than expected.
# Use the *on_bad_lines* parameter of the **read_csv** function to handle those bad lines.
# If you have implemented the function **handle_bad_line** (Task 2.1), use it to repair the bad lines. Otherwise, you can simply skip the bad lines by setting the *on_bad_lines* parameter to 'skip'.
# Show the first couple of rows of the dataframe.

# %% [markdown]
# ### Task 2.3: Encode type into name
#
# Extend the dataframe with an *Items* column where the *type* is concatenated with the *name* to encode the type (symptom, condition, treatment, node, or weather observation) into the item name.
# The result of the concatenation should be in the format "type/name", e.g., "C/headache".
# Ensure that the *Items* column does not contain any NaN values. Drop all rows where the *Items* column contains NaN values.
#
# Then group the dataframe by *reportid* and aggregate the items into a list.
# Show the first couple of rows of the resulting dataframe.

# %% [markdown]
# ### Task 2.4: Transform the transactions into the required format
#
# Obtain a one-hot encoded representation of the transactions in the format required by the Mlxtend framework.
# Use the one-hot encoded representation to create a  dataframe with the respective column names and show the first couple of rows.

# %% [markdown]
# ### Task 2.5: Obtain frequent itemsets
#
# Use the Mlxtend framework to obtain frequent itemsets with a minimum support of 5 %.
# Add a column *support_count* indicating the support count of the itemset.
# Sort the dataframe by the support count in descending order and show the first and last couple of rows.

# %% [markdown]
# ### Task 2.6: Obtain association rules
#
# From the frequent itemsets, obtain association rules with a minimum lift of 3.0 and sort the rules by lift in descending order.
#
# Show the first couple of rows of the dataframe, limited to the columns *antecedents*, *consequents*, *support*, *confidence*, *lift*, and *kulczynski*.

# %% [markdown]
# ### Task 2.7: Filter association rules and evaluate an association rule
#
# Filter out, i.e., remove, those association rules that contain a weather observation in the antecendents or consequents.
# How many rules have been removed? Show all rows of the filtered dataframe.
#
# Finally, pick one of the remaing association rules and investigate the interestingness of that association rule. Write your textual answer in the markdown cell below.

# %% [markdown]
# **How do you interpret the interestingness of the rule you picked?**
#
# -> PUT YOUR ANSWER HERE <-

# %% [markdown]
# ### Task 2.8: Calculate the imbalance ratio
#
# Add a column *imbalance_ratio* to the dataframe of the filtered rules (Task 2.7) indicating the imbalance ratio of each rule.
#
# Show all rows of the dataframe, limited to the columns *antecedents*, *consequents*, and *imbalance ratio*.
#
# Finally, judge the interestingness of the association rule you previously picked in Task 2.7 based on the imbalance ratio. Write your textual answer in the markdown cell below.

# %% [markdown]
# **How do you judge the interestingness of the association rule you previously picked now?**
#
# -> PUT YOUR ANSWER HERE <-

# %% [markdown]
# ### Task 2.9: Perform a more detailed analysis of weather conditions, notes, etc.
#
# Look more closely at the weather observations in the base dataframe. You will notice that some of the weather observations have values, e.g., 'temperature max' and 'humidity'. Employ binning to find more meaningful items than just 'W/temperature max' and 'W/humidity', e.g., 'W/temperature max 25-30' or 'W/humidity 50-60', before mining for frequent itemsets and meaningful association rules. Try out different binning strategies and see whether you can find interesting association rules, not just between weather observations but between weather observations and specifically symptoms. Look also at the notes and think about transformations that you could apply to possibly find more interesting association rules. Do you have any other ideas regarding the preprocessing?
#
# Add additional code and markdown cells to document your analysis.
